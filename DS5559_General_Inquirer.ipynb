# %% [markdown]
# # Synopsis
#
# Convert [General Inquirer lexicon](http://www.wjh.harvard.edu/~inquirer/spreadsheet_guide.htm) into usable form. Download [the spreadsheet](http://www.wjh.harvard.edu/~inquirer/inquirerbasic.xls).

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pragmas

# %%
# %matplotlib inline

# %% [markdown]
# # Process

# %% [markdown]
# ## Import Excel file
#
# It has 182 ontology/sentiment columns

# %%
df = pd.read_excel('lexicons/inquirerbasic.xls', false_values=None)

# %%
df.sample(10)
# Out:
#             Entry Source  Positiv  Negativ  Pstv Affil  Ngtv Hostile  Strong  \
# 4993       HERD#1  H4Lvd      NaN      NaN   NaN   NaN   NaN     NaN  Strong
# 1047    BELIEVE#1  H4Lvd      NaN      NaN   NaN   NaN   NaN     NaN     NaN
# 3889       FALL#3  H4Lvd      NaN      NaN   NaN   NaN   NaN     NaN     NaN
# 4160     FLAWLESS     H4  Positiv      NaN   NaN   NaN   NaN     NaN     NaN
# 8915        RUN#6     H4      NaN      NaN   NaN   NaN   NaN     NaN     NaN
# 1913   COLLECTION  H4Lvd      NaN      NaN   NaN   NaN   NaN     NaN     NaN
# 6654       MISS#3  H4Lvd      NaN      NaN   NaN   NaN   NaN     NaN     NaN
# 11185    VAGABOND     H4      NaN  Negativ   NaN   NaN   NaN     NaN     NaN
# 6954       NICE#4  H4Lvd  Positiv      NaN  Pstv   NaN   NaN     NaN     NaN
# 1177       BLOODY  H4Lvd      NaN  Negativ   NaN   NaN  Ngtv     NaN     NaN
#
#       Power                        ...                         Anomie NegAff  \
# 4993    NaN                        ...                            NaN    NaN
# 1047    NaN                        ...                            NaN    NaN
# 3889    NaN                        ...                            NaN    NaN
# 4160    NaN                        ...                            NaN    NaN
# 8915    NaN                        ...                            NaN    NaN
# 1913    NaN                        ...                            NaN    NaN
# 6654    NaN                        ...                            NaN    NaN
# 11185   NaN                        ...                            NaN    NaN
# 6954    NaN                        ...                            NaN    NaN
# 1177    NaN                        ...                            NaN    NaN
#
#        PosAff SureLw   If NotLw TimeSpc FormLw Othtags  \
# 4993      NaN    NaN  NaN   NaN     NaN    NaN    Noun
# 1047      NaN    NaN  NaN   NaN     NaN    NaN    SUPV
# 3889      NaN    NaN  NaN   NaN     NaN    NaN    SUPV
# 4160      NaN    NaN  NaN   NaN     NaN    NaN   Modif
# 8915      NaN    NaN  NaN   NaN     NaN    NaN    SUPV
# 1913      NaN    NaN  NaN   NaN     NaN    NaN    Noun
# 6654      NaN    NaN  NaN   NaN     NaN    NaN   Modif
# 11185     NaN    NaN  NaN   NaN     NaN    NaN    Noun
# 6954   PosAff    NaN  NaN   NaN     NaN    NaN      LY
# 1177      NaN    NaN  NaN   NaN     NaN    NaN   Modif
#
#                                                  Defined
# 4993                        | 61% noun-adj: Animal group
# 1047   | 68% verb: To be of the opinion that--to thin...
# 3889                      | 4% verb-idiom: 'fall asleep'
# 4160                                                   |
# 8915   | 16% verb: 'run away,' 'run off'--to flee, es...
# 1913                                                   |
# 6654                | 8% adj: "Missing"--absent, lacking
# 11185                                                  |
# 6954          | 10% adv: "Nicely"--pleasantly, agreeably
# 1177                                                   |
#
# [10 rows x 186 columns]

# %% [markdown]
# ## Handle variant terms

# %%
df['split'] = df.Entry.str.split(r'[#_]+')

# %%
# Function to add 1 to terms without variants
def add_1(x):
    try:
        if len(x) == 1:
            x = x + [1]
    except:
        print(x)
        x = 0
    return x

# %%
df['split'] = df['split'].apply(add_1)
df['term_str'] = df['split'].apply(lambda x: x[0].lower(), 1)
df['term_var'] = df['split'].apply(lambda x: x[1], 1)
df = df.set_index(['term_str', 'term_var'])

# %%
df.head()
# Out:
#                             Entry Source Positiv  Negativ Pstv Affil  Ngtv  \
# term_str    term_var
# a           1                   A  H4Lvd     NaN      NaN  NaN   NaN   NaN
# abandon     1             ABANDON  H4Lvd     NaN  Negativ  NaN   NaN  Ngtv
# abandonment 1         ABANDONMENT     H4     NaN  Negativ  NaN   NaN   NaN
# abate       1               ABATE  H4Lvd     NaN  Negativ  NaN   NaN   NaN
# abatement   1           ABATEMENT    Lvd     NaN      NaN  NaN   NaN   NaN
#
#                      Hostile Strong Power        ...        NegAff PosAff  \
# term_str    term_var                             ...
# a           1            NaN    NaN   NaN        ...           NaN    NaN
# abandon     1            NaN    NaN   NaN        ...           NaN    NaN
# abandonment 1            NaN    NaN   NaN        ...           NaN    NaN
# abate       1            NaN    NaN   NaN        ...           NaN    NaN
# abatement   1            NaN    NaN   NaN        ...           NaN    NaN
#
#                      SureLw   If NotLw TimeSpc FormLw  Othtags  \
# term_str    term_var
# a           1           NaN  NaN   NaN     NaN    NaN  DET ART
# abandon     1           NaN  NaN   NaN     NaN    NaN     SUPV
# abandonment 1           NaN  NaN   NaN     NaN    NaN     Noun
# abate       1           NaN  NaN   NaN     NaN    NaN     SUPV
# abatement   1           NaN  NaN   NaN     NaN    NaN     Noun
#
#                                                                 Defined  \
# term_str    term_var
# a           1         | article: Indefinite singular article--some o...
# abandon     1                                                         |
# abandonment 1                                                         |
# abate       1                                                         |
# abatement   1                                                       NaN
#
#                                  split
# term_str    term_var
# a           1                   [A, 1]
# abandon     1             [ABANDON, 1]
# abandonment 1         [ABANDONMENT, 1]
# abate       1               [ABATE, 1]
# abatement   1           [ABATEMENT, 1]
#
# [5 rows x 187 columns]

# %% [markdown]
# ## Convert column values to numbers

# %%
try:
    df.loc[df.Positiv == 'Positiv', 'polarity'] = 1
    df.loc[df.Negativ == 'Negativ', 'polarity'] = -1
    df['polarity'] = df['polarity'].fillna(0)
except TypeError as e:
    print(e, "--  This means you are re-running the script with values that have already been set.")
# Out:
# /apps/software/standard/core/anaconda/5.2.0-py3.6/lib/python3.6/site-packages/ipykernel/ipkernel.py:208: PerformanceWarning: indexing past lexsort depth may impact performance.
#   res = shell.run_cell(code, store_history=store_history, silent=silent)

# %%
df.polarity.sample(10)
# Out:
# term_str    term_var
# triumphant  1           1.0
# resistance  1           0.0
# tribe       1           0.0
# obstinate   1          -1.0
# compass     1           0.0
# trace       1           0.0
# accession   1           1.0
# smitten     1           1.0
# convey      1           0.0
# clerk       1           0.0
# Name: polarity, dtype: float64

# %%
VALCOLS = df.columns[2:-4]

# %%
for col in VALCOLS:
    df[col] = df[col].fillna(0).astype('bool').astype('int')

# %%
df.loc['love', VALCOLS].stack().sort_values(ascending=False)
# Out:
# term_var
# 1         Positiv    1
# 5         Active     1
# 2         AffOth     1
# 1         AffTot     1
#           AffGain    1
# 5         SocRel     1
# 3         AffGain    1
#           AffTot     1
# 1         SV         1
# 5         Strong     1
# 4         AffGain    1
# 5         Affil      1
# 4         Positiv    1
#           Pstv       1
#           Affil      1
#           Passive    1
#           Pleasur    1
#           EMOT       1
# 2         Positiv    1
#           Pstv       1
#           Affil      1
#           Passive    1
# 6         SocRel     1
#           Affil      1
# 3         Positiv    1
#           Pstv       1
#           Affil      1
#           Passive    1
#           Pleasur    1
#           EMOT       1
#                     ..
# 5         RcGain     0
#           RcEnds     0
#           Self       0
#           RcTot      0
#           RspGain    0
#           RspLoss    0
#           RspOth     0
#           RspTot     0
#           AffLoss    0
#           AffPt      0
#           PowPt      0
#           PowAuPt    0
#           PowCoop    0
#           PowCon     0
#           Our        0
#           You        0
#           Name       0
#           Yes        0
#           No         0
#           Negate     0
#           Intrj      0
#           DAV        0
#           SV         0
#           IPadj      0
#           IndAdj     0
#           PowGain    0
#           PowLoss    0
#           PowEnds    0
#           PowAren    0
# 4         Abs@       0
# Length: 1274, dtype: int64

# %%
# # Handle terms with multiple entries
# VAR_COUNTS = df.reset_index().groupby(['term_str']).term_var.count()\
#     .to_frame().rename(columns={'term_var':'n_vars'})
# SINGLES = VAR_COUNTS == 1
# SINGLES.head()
# df.loc['a'].T
# df.loc[SINGLES.n_vars.values]

# %% [markdown]
# ## Take and combine only sentiment

# %%
sents = df.query("Positiv > 0 | Negativ > 0").copy()

# %%
sents['sentiment'] =  sents.Positiv  - sents.Negativ

# %%
sents['sentiment'].sample(5)
# Out:
# term_str    term_var
# confidence  1           1
# inane       1          -1
# fine        1           1
# symbolize   1           1
# value       3           1
# Name: sentiment, dtype: int64

# %% [markdown]
# ### Take average of variants

# %%
GI = sents.groupby('term_str').sentiment.mean()

# %% [markdown]
# ### Snap values to -1, 0, or 1

# %%
GI = np.sign(GI).astype('int').to_frame()

# %%
GI.shape
# Out:
# (3626, 1)

# %%
GI.head()
# Out:
#              sentiment
# term_str
# abandon             -1
# abandonment         -1
# abate               -1
# abdicate            -1
# abhor               -1

# %% [markdown]
# # Save

# %%
GI.to_csv('lexicons/gi.csv')
